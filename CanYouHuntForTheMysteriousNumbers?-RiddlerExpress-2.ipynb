# %%
import pandas as pd

products = [210, 144, 54, 135, 4, 49]

hdict = []

for p in products:
    for i in range(10):
        for j in range(10):
            for k in range(10):
                product = i*j*k
                # print("The product of {}*{}*{} = {}".format(i, j, k, product))
                if product == p:
                    print("The product of {}*{}*{} = {} and product = {}".format(i, j, k, product, p))
                    h = {'i':i, 'j':j, 'k':k, 'product':product, 'p':p}
                    hdict.append(h)

hdf = pd.DataFrame(hdict, columns=['i','j','k','product','p'])
hdf.head()
# Out:
# The product of 5*6*7 = 210 and product = 210
# The product of 5*7*6 = 210 and product = 210
# The product of 6*5*7 = 210 and product = 210
# The product of 6*7*5 = 210 and product = 210
# The product of 7*5*6 = 210 and product = 210
# The product of 7*6*5 = 210 and product = 210
# The product of 2*8*9 = 144 and product = 144
# The product of 2*9*8 = 144 and product = 144
# The product of 3*6*8 = 144 and product = 144
# The product of 3*8*6 = 144 and product = 144
# The product of 4*4*9 = 144 and product = 144
# The product of 4*6*6 = 144 and product = 144
# The product of 4*9*4 = 144 and product = 144
# The product of 6*3*8 = 144 and product = 144
# The product of 6*4*6 = 144 and product = 144
# The product of 6*6*4 = 144 and product = 144
# The product of 6*8*3 = 144 and product = 144
# The product of 8*2*9 = 144 and product = 144
# The product of 8*3*6 = 144 and product = 144
# The product of 8*6*3 = 144 and product = 144
# The product of 8*9*2 = 144 and product = 144
# The product of 9*2*8 = 144 and product = 144
# The product of 9*4*4 = 144 and product = 144
# The product of 9*8*2 = 144 and product = 144
# The product of 1*6*9 = 54 and product = 54
# The product of 1*9*6 = 54 and product = 54
# The product of 2*3*9 = 54 and product = 54
# The product of 2*9*3 = 54 and product = 54
# The product of 3*2*9 = 54 and product = 54
# The product of 3*3*6 = 54 and product = 54
# The product of 3*6*3 = 54 and product = 54
# The product of 3*9*2 = 54 and product = 54
# The product of 6*1*9 = 54 and product = 54
# The product of 6*3*3 = 54 and product = 54
# The product of 6*9*1 = 54 and product = 54
# The product of 9*1*6 = 54 and product = 54
# The product of 9*2*3 = 54 and product = 54
# The product of 9*3*2 = 54 and product = 54
# The product of 9*6*1 = 54 and product = 54
# The product of 3*5*9 = 135 and product = 135
# The product of 3*9*5 = 135 and product = 135
# The product of 5*3*9 = 135 and product = 135
# The product of 5*9*3 = 135 and product = 135
# The product of 9*3*5 = 135 and product = 135
# The product of 9*5*3 = 135 and product = 135
# The product of 1*1*4 = 4 and product = 4
# The product of 1*2*2 = 4 and product = 4
# The product of 1*4*1 = 4 and product = 4
# The product of 2*1*2 = 4 and product = 4
# The product of 2*2*1 = 4 and product = 4
# The product of 4*1*1 = 4 and product = 4
# The product of 1*7*7 = 49 and product = 49
# The product of 7*1*7 = 49 and product = 49
# The product of 7*7*1 = 49 and product = 49
#    i  j  k  product    p
# 0  5  6  7      210  210
# 1  5  7  6      210  210
# 2  6  5  7      210  210
# 3  6  7  5      210  210
# 4  7  5  6      210  210

# %%
products = [6615, 15552, 420]

vdict = []

for p in products:
    for a in range(10):
        for b in range(10):
            for c in range(10):
                for d in range(10):
                    for e in range(10):
                        for f in range(10):
                            product = a*b*c*d*e*f
                            # print("The product of {}*{}*{} = {}".format(i, j, k, product))
                            if product == p:
                                solution = "{}*{}*{}*{}*{}".format(a, b, c, d, e, f)
                                print("The product of {}*{}*{}*{}*{}*{} = {} and product = {}".format(a, b, c, d, e, f, product, p))
                                v = {'a':a, 'b':b, 'c':c, 'd':d, 'e':e, 'f':f, 'product':product, 'p':p}
                                vdict.append(v)

vdf = pd.DataFrame(vdict, columns=['a','b','c','d','e','f','product','p'])
vdf.head()
# Out:
# The product of 1*3*5*7*7*9 = 6615 and product = 6615
# The product of 1*3*5*7*9*7 = 6615 and product = 6615
# The product of 1*3*5*9*7*7 = 6615 and product = 6615
# The product of 1*3*7*5*7*9 = 6615 and product = 6615
# The product of 1*3*7*5*9*7 = 6615 and product = 6615
# The product of 1*3*7*7*5*9 = 6615 and product = 6615
# The product of 1*3*7*7*9*5 = 6615 and product = 6615
# The product of 1*3*7*9*5*7 = 6615 and product = 6615
# The product of 1*3*7*9*7*5 = 6615 and product = 6615
# The product of 1*3*9*5*7*7 = 6615 and product = 6615
# The product of 1*3*9*7*5*7 = 6615 and product = 6615
# The product of 1*3*9*7*7*5 = 6615 and product = 6615
# The product of 1*5*3*7*7*9 = 6615 and product = 6615
# The product of 1*5*3*7*9*7 = 6615 and product = 6615
# The product of 1*5*3*9*7*7 = 6615 and product = 6615
# The product of 1*5*7*3*7*9 = 6615 and product = 6615
# The product of 1*5*7*3*9*7 = 6615 and product = 6615
# The product of 1*5*7*7*3*9 = 6615 and product = 6615
# The product of 1*5*7*7*9*3 = 6615 and product = 6615
# The product of 1*5*7*9*3*7 = 6615 and product = 6615
# The product of 1*5*7*9*7*3 = 6615 and product = 6615
# The product of 1*5*9*3*7*7 = 6615 and product = 6615
# The product of 1*5*9*7*3*7 = 6615 and product = 6615
# The product of 1*5*9*7*7*3 = 6615 and product = 6615
# The product of 1*7*3*5*7*9 = 6615 and product = 6615
# The product of 1*7*3*5*9*7 = 6615 and product = 6615
# The product of 1*7*3*7*5*9 = 6615 and product = 6615
# The product of 1*7*3*7*9*5 = 6615 and product = 6615
# The product of 1*7*3*9*5*7 = 6615 and product = 6615
# The product of 1*7*3*9*7*5 = 6615 and product = 6615
# The product of 1*7*5*3*7*9 = 6615 and product = 6615
# The product of 1*7*5*3*9*7 = 6615 and product = 6615
# The product of 1*7*5*7*3*9 = 6615 and product = 6615
# The product of 1*7*5*7*9*3 = 6615 and product = 6615
# The product of 1*7*5*9*3*7 = 6615 and product = 6615
# The product of 1*7*5*9*7*3 = 6615 and product = 6615
# The product of 1*7*7*3*5*9 = 6615 and product = 6615
# The product of 1*7*7*3*9*5 = 6615 and product = 6615
# The product of 1*7*7*5*3*9 = 6615 and product = 6615
# The product of 1*7*7*5*9*3 = 6615 and product = 6615
# The product of 1*7*7*9*3*5 = 6615 and product = 6615
# The product of 1*7*7*9*5*3 = 6615 and product = 6615
# The product of 1*7*9*3*5*7 = 6615 and product = 6615
# The product of 1*7*9*3*7*5 = 6615 and product = 6615
# The product of 1*7*9*5*3*7 = 6615 and product = 6615
# The product of 1*7*9*5*7*3 = 6615 and product = 6615
# The product of 1*7*9*7*3*5 = 6615 and product = 6615
# The product of 1*7*9*7*5*3 = 6615 and product = 6615
# The product of 1*9*3*5*7*7 = 6615 and product = 6615
# The product of 1*9*3*7*5*7 = 6615 and product = 6615
# The product of 1*9*3*7*7*5 = 6615 and product = 6615
# The product of 1*9*5*3*7*7 = 6615 and product = 6615
# The product of 1*9*5*7*3*7 = 6615 and product = 6615
# The product of 1*9*5*7*7*3 = 6615 and product = 6615
# The product of 1*9*7*3*5*7 = 6615 and product = 6615
# The product of 1*9*7*3*7*5 = 6615 and product = 6615
# The product of 1*9*7*5*3*7 = 6615 and product = 6615
# The product of 1*9*7*5*7*3 = 6615 and product = 6615
# The product of 1*9*7*7*3*5 = 6615 and product = 6615
# The product of 1*9*7*7*5*3 = 6615 and product = 6615
# The product of 3*1*5*7*7*9 = 6615 and product = 6615
# The product of 3*1*5*7*9*7 = 6615 and product = 6615
# The product of 3*1*5*9*7*7 = 6615 and product = 6615
# The product of 3*1*7*5*7*9 = 6615 and product = 6615
# The product of 3*1*7*5*9*7 = 6615 and product = 6615
# The product of 3*1*7*7*5*9 = 6615 and product = 6615
# The product of 3*1*7*7*9*5 = 6615 and product = 6615
# The product of 3*1*7*9*5*7 = 6615 and product = 6615
# The product of 3*1*7*9*7*5 = 6615 and product = 6615
# The product of 3*1*9*5*7*7 = 6615 and product = 6615
# The product of 3*1*9*7*5*7 = 6615 and product = 6615
# The product of 3*1*9*7*7*5 = 6615 and product = 6615
# The product of 3*3*3*5*7*7 = 6615 and product = 6615
# The product of 3*3*3*7*5*7 = 6615 and product = 6615
# The product of 3*3*3*7*7*5 = 6615 and product = 6615
# The product of 3*3*5*3*7*7 = 6615 and product = 6615
# The product of 3*3*5*7*3*7 = 6615 and product = 6615
# The product of 3*3*5*7*7*3 = 6615 and product = 6615
# The product of 3*3*7*3*5*7 = 6615 and product = 6615
# The product of 3*3*7*3*7*5 = 6615 and product = 6615
# The product of 3*3*7*5*3*7 = 6615 and product = 6615
# The product of 3*3*7*5*7*3 = 6615 and product = 6615
# The product of 3*3*7*7*3*5 = 6615 and product = 6615
# The product of 3*3*7*7*5*3 = 6615 and product = 6615
# The product of 3*5*1*7*7*9 = 6615 and product = 6615
# The product of 3*5*1*7*9*7 = 6615 and product = 6615
# The product of 3*5*1*9*7*7 = 6615 and product = 6615
# The product of 3*5*3*3*7*7 = 6615 and product = 6615
# The product of 3*5*3*7*3*7 = 6615 and product = 6615
# The product of 3*5*3*7*7*3 = 6615 and product = 6615
# The product of 3*5*7*1*7*9 = 6615 and product = 6615
# The product of 3*5*7*1*9*7 = 6615 and product = 6615
# The product of 3*5*7*3*3*7 = 6615 and product = 6615
# The product of 3*5*7*3*7*3 = 6615 and product = 6615
# The product of 3*5*7*7*1*9 = 6615 and product = 6615
# The product of 3*5*7*7*3*3 = 6615 and product = 6615
# The product of 3*5*7*7*9*1 = 6615 and product = 6615
# The product of 3*5*7*9*1*7 = 6615 and product = 6615
# The product of 3*5*7*9*7*1 = 6615 and product = 6615
# The product of 3*5*9*1*7*7 = 6615 and product = 6615
# The product of 3*5*9*7*1*7 = 6615 and product = 6615
# The product of 3*5*9*7*7*1 = 6615 and product = 6615
# The product of 3*7*1*5*7*9 = 6615 and product = 6615
# The product of 3*7*1*5*9*7 = 6615 and product = 6615
# The product of 3*7*1*7*5*9 = 6615 and product = 6615
# The product of 3*7*1*7*9*5 = 6615 and product = 6615
# The product of 3*7*1*9*5*7 = 6615 and product = 6615
# The product of 3*7*1*9*7*5 = 6615 and product = 6615
# The product of 3*7*3*3*5*7 = 6615 and product = 6615
# The product of 3*7*3*3*7*5 = 6615 and product = 6615
# The product of 3*7*3*5*3*7 = 6615 and product = 6615
# The product of 3*7*3*5*7*3 = 6615 and product = 6615
# The product of 3*7*3*7*3*5 = 6615 and product = 6615
# The product of 3*7*3*7*5*3 = 6615 and product = 6615
# The product of 3*7*5*1*7*9 = 6615 and product = 6615
# The product of 3*7*5*1*9*7 = 6615 and product = 6615
# The product of 3*7*5*3*3*7 = 6615 and product = 6615
# The product of 3*7*5*3*7*3 = 6615 and product = 6615
# The product of 3*7*5*7*1*9 = 6615 and product = 6615
# The product of 3*7*5*7*3*3 = 6615 and product = 6615
# The product of 3*7*5*7*9*1 = 6615 and product = 6615
# The product of 3*7*5*9*1*7 = 6615 and product = 6615
# The product of 3*7*5*9*7*1 = 6615 and product = 6615
# The product of 3*7*7*1*5*9 = 6615 and product = 6615
# The product of 3*7*7*1*9*5 = 6615 and product = 6615
# The product of 3*7*7*3*3*5 = 6615 and product = 6615
# The product of 3*7*7*3*5*3 = 6615 and product = 6615
# The product of 3*7*7*5*1*9 = 6615 and product = 6615
# The product of 3*7*7*5*3*3 = 6615 and product = 6615
# The product of 3*7*7*5*9*1 = 6615 and product = 6615
# The product of 3*7*7*9*1*5 = 6615 and product = 6615
# The product of 3*7*7*9*5*1 = 6615 and product = 6615
# The product of 3*7*9*1*5*7 = 6615 and product = 6615
# The product of 3*7*9*1*7*5 = 6615 and product = 6615
# The product of 3*7*9*5*1*7 = 6615 and product = 6615
# The product of 3*7*9*5*7*1 = 6615 and product = 6615
# The product of 3*7*9*7*1*5 = 6615 and product = 6615
# The product of 3*7*9*7*5*1 = 6615 and product = 6615
# The product of 3*9*1*5*7*7 = 6615 and product = 6615
# The product of 3*9*1*7*5*7 = 6615 and product = 6615
# The product of 3*9*1*7*7*5 = 6615 and product = 6615
# The product of 3*9*5*1*7*7 = 6615 and product = 6615
# The product of 3*9*5*7*1*7 = 6615 and product = 6615
# The product of 3*9*5*7*7*1 = 6615 and product = 6615
# The product of 3*9*7*1*5*7 = 6615 and product = 6615
# The product of 3*9*7*1*7*5 = 6615 and product = 6615
# The product of 3*9*7*5*1*7 = 6615 and product = 6615
# The product of 3*9*7*5*7*1 = 6615 and product = 6615
# The product of 3*9*7*7*1*5 = 6615 and product = 6615
# The product of 3*9*7*7*5*1 = 6615 and product = 6615
# The product of 5*1*3*7*7*9 = 6615 and product = 6615
# The product of 5*1*3*7*9*7 = 6615 and product = 6615
# The product of 5*1*3*9*7*7 = 6615 and product = 6615
# The product of 5*1*7*3*7*9 = 6615 and product = 6615
# The product of 5*1*7*3*9*7 = 6615 and product = 6615
# The product of 5*1*7*7*3*9 = 6615 and product = 6615
# The product of 5*1*7*7*9*3 = 6615 and product = 6615
# The product of 5*1*7*9*3*7 = 6615 and product = 6615
# The product of 5*1*7*9*7*3 = 6615 and product = 6615
# The product of 5*1*9*3*7*7 = 6615 and product = 6615
# The product of 5*1*9*7*3*7 = 6615 and product = 6615
# The product of 5*1*9*7*7*3 = 6615 and product = 6615
# The product of 5*3*1*7*7*9 = 6615 and product = 6615
# The product of 5*3*1*7*9*7 = 6615 and product = 6615
# The product of 5*3*1*9*7*7 = 6615 and product = 6615
# The product of 5*3*3*3*7*7 = 6615 and product = 6615
# The product of 5*3*3*7*3*7 = 6615 and product = 6615
# The product of 5*3*3*7*7*3 = 6615 and product = 6615
# The product of 5*3*7*1*7*9 = 6615 and product = 6615
# The product of 5*3*7*1*9*7 = 6615 and product = 6615
# The product of 5*3*7*3*3*7 = 6615 and product = 6615
# The product of 5*3*7*3*7*3 = 6615 and product = 6615
# The product of 5*3*7*7*1*9 = 6615 and product = 6615
# The product of 5*3*7*7*3*3 = 6615 and product = 6615
# The product of 5*3*7*7*9*1 = 6615 and product = 6615
# The product of 5*3*7*9*1*7 = 6615 and product = 6615
# The product of 5*3*7*9*7*1 = 6615 and product = 6615
# The product of 5*3*9*1*7*7 = 6615 and product = 6615
# The product of 5*3*9*7*1*7 = 6615 and product = 6615
# The product of 5*3*9*7*7*1 = 6615 and product = 6615
# The product of 5*7*1*3*7*9 = 6615 and product = 6615
# The product of 5*7*1*3*9*7 = 6615 and product = 6615
# The product of 5*7*1*7*3*9 = 6615 and product = 6615
# The product of 5*7*1*7*9*3 = 6615 and product = 6615
# The product of 5*7*1*9*3*7 = 6615 and product = 6615
# The product of 5*7*1*9*7*3 = 6615 and product = 6615
# The product of 5*7*3*1*7*9 = 6615 and product = 6615
# The product of 5*7*3*1*9*7 = 6615 and product = 6615
# The product of 5*7*3*3*3*7 = 6615 and product = 6615
# The product of 5*7*3*3*7*3 = 6615 and product = 6615
# The product of 5*7*3*7*1*9 = 6615 and product = 6615
# The product of 5*7*3*7*3*3 = 6615 and product = 6615
# The product of 5*7*3*7*9*1 = 6615 and product = 6615
# The product of 5*7*3*9*1*7 = 6615 and product = 6615
# The product of 5*7*3*9*7*1 = 6615 and product = 6615
# The product of 5*7*7*1*3*9 = 6615 and product = 6615
# The product of 5*7*7*1*9*3 = 6615 and product = 6615
# The product of 5*7*7*3*1*9 = 6615 and product = 6615
# The product of 5*7*7*3*3*3 = 6615 and product = 6615
# The product of 5*7*7*3*9*1 = 6615 and product = 6615
# The product of 5*7*7*9*1*3 = 6615 and product = 6615
# The product of 5*7*7*9*3*1 = 6615 and product = 6615
# The product of 5*7*9*1*3*7 = 6615 and product = 6615
# The product of 5*7*9*1*7*3 = 6615 and product = 6615
# The product of 5*7*9*3*1*7 = 6615 and product = 6615
# The product of 5*7*9*3*7*1 = 6615 and product = 6615
# The product of 5*7*9*7*1*3 = 6615 and product = 6615
# The product of 5*7*9*7*3*1 = 6615 and product = 6615
# The product of 5*9*1*3*7*7 = 6615 and product = 6615
# The product of 5*9*1*7*3*7 = 6615 and product = 6615
# The product of 5*9*1*7*7*3 = 6615 and product = 6615
# The product of 5*9*3*1*7*7 = 6615 and product = 6615
# The product of 5*9*3*7*1*7 = 6615 and product = 6615
# The product of 5*9*3*7*7*1 = 6615 and product = 6615
# The product of 5*9*7*1*3*7 = 6615 and product = 6615
# The product of 5*9*7*1*7*3 = 6615 and product = 6615
# The product of 5*9*7*3*1*7 = 6615 and product = 6615
# The product of 5*9*7*3*7*1 = 6615 and product = 6615
# The product of 5*9*7*7*1*3 = 6615 and product = 6615
# The product of 5*9*7*7*3*1 = 6615 and product = 6615
# The product of 7*1*3*5*7*9 = 6615 and product = 6615
# The product of 7*1*3*5*9*7 = 6615 and product = 6615
# The product of 7*1*3*7*5*9 = 6615 and product = 6615
# The product of 7*1*3*7*9*5 = 6615 and product = 6615
# The product of 7*1*3*9*5*7 = 6615 and product = 6615
# The product of 7*1*3*9*7*5 = 6615 and product = 6615
# The product of 7*1*5*3*7*9 = 6615 and product = 6615
# The product of 7*1*5*3*9*7 = 6615 and product = 6615
# The product of 7*1*5*7*3*9 = 6615 and product = 6615
# The product of 7*1*5*7*9*3 = 6615 and product = 6615
# The product of 7*1*5*9*3*7 = 6615 and product = 6615
# The product of 7*1*5*9*7*3 = 6615 and product = 6615
# The product of 7*1*7*3*5*9 = 6615 and product = 6615
# The product of 7*1*7*3*9*5 = 6615 and product = 6615
# The product of 7*1*7*5*3*9 = 6615 and product = 6615
# The product of 7*1*7*5*9*3 = 6615 and product = 6615
# The product of 7*1*7*9*3*5 = 6615 and product = 6615
# The product of 7*1*7*9*5*3 = 6615 and product = 6615
# The product of 7*1*9*3*5*7 = 6615 and product = 6615
# The product of 7*1*9*3*7*5 = 6615 and product = 6615
# The product of 7*1*9*5*3*7 = 6615 and product = 6615
# The product of 7*1*9*5*7*3 = 6615 and product = 6615
# The product of 7*1*9*7*3*5 = 6615 and product = 6615
# The product of 7*1*9*7*5*3 = 6615 and product = 6615
# The product of 7*3*1*5*7*9 = 6615 and product = 6615
# The product of 7*3*1*5*9*7 = 6615 and product = 6615
# The product of 7*3*1*7*5*9 = 6615 and product = 6615
# The product of 7*3*1*7*9*5 = 6615 and product = 6615
# The product of 7*3*1*9*5*7 = 6615 and product = 6615
# The product of 7*3*1*9*7*5 = 6615 and product = 6615
# The product of 7*3*3*3*5*7 = 6615 and product = 6615
# The product of 7*3*3*3*7*5 = 6615 and product = 6615
# The product of 7*3*3*5*3*7 = 6615 and product = 6615
# The product of 7*3*3*5*7*3 = 6615 and product = 6615
# The product of 7*3*3*7*3*5 = 6615 and product = 6615
# The product of 7*3*3*7*5*3 = 6615 and product = 6615
# The product of 7*3*5*1*7*9 = 6615 and product = 6615
# The product of 7*3*5*1*9*7 = 6615 and product = 6615
# The product of 7*3*5*3*3*7 = 6615 and product = 6615
# The product of 7*3*5*3*7*3 = 6615 and product = 6615
# The product of 7*3*5*7*1*9 = 6615 and product = 6615
# The product of 7*3*5*7*3*3 = 6615 and product = 6615
# The product of 7*3*5*7*9*1 = 6615 and product = 6615
# The product of 7*3*5*9*1*7 = 6615 and product = 6615
# The product of 7*3*5*9*7*1 = 6615 and product = 6615
# The product of 7*3*7*1*5*9 = 6615 and product = 6615
# The product of 7*3*7*1*9*5 = 6615 and product = 6615
# The product of 7*3*7*3*3*5 = 6615 and product = 6615
# The product of 7*3*7*3*5*3 = 6615 and product = 6615
# The product of 7*3*7*5*1*9 = 6615 and product = 6615
# The product of 7*3*7*5*3*3 = 6615 and product = 6615
# The product of 7*3*7*5*9*1 = 6615 and product = 6615
# The product of 7*3*7*9*1*5 = 6615 and product = 6615
# The product of 7*3*7*9*5*1 = 6615 and product = 6615
# The product of 7*3*9*1*5*7 = 6615 and product = 6615
# The product of 7*3*9*1*7*5 = 6615 and product = 6615
# The product of 7*3*9*5*1*7 = 6615 and product = 6615
# The product of 7*3*9*5*7*1 = 6615 and product = 6615
# The product of 7*3*9*7*1*5 = 6615 and product = 6615
# The product of 7*3*9*7*5*1 = 6615 and product = 6615
# The product of 7*5*1*3*7*9 = 6615 and product = 6615
# The product of 7*5*1*3*9*7 = 6615 and product = 6615
# The product of 7*5*1*7*3*9 = 6615 and product = 6615
# The product of 7*5*1*7*9*3 = 6615 and product = 6615
# The product of 7*5*1*9*3*7 = 6615 and product = 6615
# The product of 7*5*1*9*7*3 = 6615 and product = 6615
# The product of 7*5*3*1*7*9 = 6615 and product = 6615
# The product of 7*5*3*1*9*7 = 6615 and product = 6615
# The product of 7*5*3*3*3*7 = 6615 and product = 6615
# The product of 7*5*3*3*7*3 = 6615 and product = 6615
# The product of 7*5*3*7*1*9 = 6615 and product = 6615
# The product of 7*5*3*7*3*3 = 6615 and product = 6615
# The product of 7*5*3*7*9*1 = 6615 and product = 6615
# The product of 7*5*3*9*1*7 = 6615 and product = 6615
# The product of 7*5*3*9*7*1 = 6615 and product = 6615
# The product of 7*5*7*1*3*9 = 6615 and product = 6615
# The product of 7*5*7*1*9*3 = 6615 and product = 6615
# The product of 7*5*7*3*1*9 = 6615 and product = 6615
# The product of 7*5*7*3*3*3 = 6615 and product = 6615
# The product of 7*5*7*3*9*1 = 6615 and product = 6615
# The product of 7*5*7*9*1*3 = 6615 and product = 6615
# The product of 7*5*7*9*3*1 = 6615 and product = 6615
# The product of 7*5*9*1*3*7 = 6615 and product = 6615
# The product of 7*5*9*1*7*3 = 6615 and product = 6615
# The product of 7*5*9*3*1*7 = 6615 and product = 6615
# The product of 7*5*9*3*7*1 = 6615 and product = 6615
# The product of 7*5*9*7*1*3 = 6615 and product = 6615
# The product of 7*5*9*7*3*1 = 6615 and product = 6615
# The product of 7*7*1*3*5*9 = 6615 and product = 6615
# The product of 7*7*1*3*9*5 = 6615 and product = 6615
# The product of 7*7*1*5*3*9 = 6615 and product = 6615
# The product of 7*7*1*5*9*3 = 6615 and product = 6615
# The product of 7*7*1*9*3*5 = 6615 and product = 6615
# The product of 7*7*1*9*5*3 = 6615 and product = 6615
# The product of 7*7*3*1*5*9 = 6615 and product = 6615
# The product of 7*7*3*1*9*5 = 6615 and product = 6615
# The product of 7*7*3*3*3*5 = 6615 and product = 6615
# The product of 7*7*3*3*5*3 = 6615 and product = 6615
# The product of 7*7*3*5*1*9 = 6615 and product = 6615
# The product of 7*7*3*5*3*3 = 6615 and product = 6615
# The product of 7*7*3*5*9*1 = 6615 and product = 6615
# The product of 7*7*3*9*1*5 = 6615 and product = 6615
# The product of 7*7*3*9*5*1 = 6615 and product = 6615
# The product of 7*7*5*1*3*9 = 6615 and product = 6615
# The product of 7*7*5*1*9*3 = 6615 and product = 6615
# The product of 7*7*5*3*1*9 = 6615 and product = 6615
# The product of 7*7*5*3*3*3 = 6615 and product = 6615
# The product of 7*7*5*3*9*1 = 6615 and product = 6615
# The product of 7*7*5*9*1*3 = 6615 and product = 6615
# The product of 7*7*5*9*3*1 = 6615 and product = 6615
# The product of 7*7*9*1*3*5 = 6615 and product = 6615
# The product of 7*7*9*1*5*3 = 6615 and product = 6615
# The product of 7*7*9*3*1*5 = 6615 and product = 6615
# The product of 7*7*9*3*5*1 = 6615 and product = 6615
# The product of 7*7*9*5*1*3 = 6615 and product = 6615
# The product of 7*7*9*5*3*1 = 6615 and product = 6615
# The product of 7*9*1*3*5*7 = 6615 and product = 6615
# The product of 7*9*1*3*7*5 = 6615 and product = 6615
# The product of 7*9*1*5*3*7 = 6615 and product = 6615
# The product of 7*9*1*5*7*3 = 6615 and product = 6615
# The product of 7*9*1*7*3*5 = 6615 and product = 6615
# The product of 7*9*1*7*5*3 = 6615 and product = 6615
# The product of 7*9*3*1*5*7 = 6615 and product = 6615
# The product of 7*9*3*1*7*5 = 6615 and product = 6615
# The product of 7*9*3*5*1*7 = 6615 and product = 6615
# The product of 7*9*3*5*7*1 = 6615 and product = 6615
# The product of 7*9*3*7*1*5 = 6615 and product = 6615
# The product of 7*9*3*7*5*1 = 6615 and product = 6615
# The product of 7*9*5*1*3*7 = 6615 and product = 6615
# The product of 7*9*5*1*7*3 = 6615 and product = 6615
# The product of 7*9*5*3*1*7 = 6615 and product = 6615
# The product of 7*9*5*3*7*1 = 6615 and product = 6615
# The product of 7*9*5*7*1*3 = 6615 and product = 6615
# The product of 7*9*5*7*3*1 = 6615 and product = 6615
# The product of 7*9*7*1*3*5 = 6615 and product = 6615
# The product of 7*9*7*1*5*3 = 6615 and product = 6615
# The product of 7*9*7*3*1*5 = 6615 and product = 6615
# The product of 7*9*7*3*5*1 = 6615 and product = 6615
# The product of 7*9*7*5*1*3 = 6615 and product = 6615
# The product of 7*9*7*5*3*1 = 6615 and product = 6615
# The product of 9*1*3*5*7*7 = 6615 and product = 6615
# The product of 9*1*3*7*5*7 = 6615 and product = 6615
# The product of 9*1*3*7*7*5 = 6615 and product = 6615
# The product of 9*1*5*3*7*7 = 6615 and product = 6615
# The product of 9*1*5*7*3*7 = 6615 and product = 6615
# The product of 9*1*5*7*7*3 = 6615 and product = 6615
# The product of 9*1*7*3*5*7 = 6615 and product = 6615
# The product of 9*1*7*3*7*5 = 6615 and product = 6615
# The product of 9*1*7*5*3*7 = 6615 and product = 6615
# The product of 9*1*7*5*7*3 = 6615 and product = 6615
# The product of 9*1*7*7*3*5 = 6615 and product = 6615
# The product of 9*1*7*7*5*3 = 6615 and product = 6615
# The product of 9*3*1*5*7*7 = 6615 and product = 6615
# The product of 9*3*1*7*5*7 = 6615 and product = 6615
# The product of 9*3*1*7*7*5 = 6615 and product = 6615
# The product of 9*3*5*1*7*7 = 6615 and product = 6615
# The product of 9*3*5*7*1*7 = 6615 and product = 6615
# The product of 9*3*5*7*7*1 = 6615 and product = 6615
# The product of 9*3*7*1*5*7 = 6615 and product = 6615
# The product of 9*3*7*1*7*5 = 6615 and product = 6615
# The product of 9*3*7*5*1*7 = 6615 and product = 6615
# The product of 9*3*7*5*7*1 = 6615 and product = 6615
# The product of 9*3*7*7*1*5 = 6615 and product = 6615
# The product of 9*3*7*7*5*1 = 6615 and product = 6615
# The product of 9*5*1*3*7*7 = 6615 and product = 6615
# The product of 9*5*1*7*3*7 = 6615 and product = 6615
# The product of 9*5*1*7*7*3 = 6615 and product = 6615
# The product of 9*5*3*1*7*7 = 6615 and product = 6615
# The product of 9*5*3*7*1*7 = 6615 and product = 6615
# The product of 9*5*3*7*7*1 = 6615 and product = 6615
# The product of 9*5*7*1*3*7 = 6615 and product = 6615
# The product of 9*5*7*1*7*3 = 6615 and product = 6615
# The product of 9*5*7*3*1*7 = 6615 and product = 6615
# The product of 9*5*7*3*7*1 = 6615 and product = 6615
# The product of 9*5*7*7*1*3 = 6615 and product = 6615
# The product of 9*5*7*7*3*1 = 6615 and product = 6615
# The product of 9*7*1*3*5*7 = 6615 and product = 6615
# The product of 9*7*1*3*7*5 = 6615 and product = 6615
# The product of 9*7*1*5*3*7 = 6615 and product = 6615
# The product of 9*7*1*5*7*3 = 6615 and product = 6615
# The product of 9*7*1*7*3*5 = 6615 and product = 6615
# The product of 9*7*1*7*5*3 = 6615 and product = 6615
# The product of 9*7*3*1*5*7 = 6615 and product = 6615
# The product of 9*7*3*1*7*5 = 6615 and product = 6615
# The product of 9*7*3*5*1*7 = 6615 and product = 6615
# The product of 9*7*3*5*7*1 = 6615 and product = 6615
# The product of 9*7*3*7*1*5 = 6615 and product = 6615
# The product of 9*7*3*7*5*1 = 6615 and product = 6615
# The product of 9*7*5*1*3*7 = 6615 and product = 6615
# The product of 9*7*5*1*7*3 = 6615 and product = 6615
# The product of 9*7*5*3*1*7 = 6615 and product = 6615
# The product of 9*7*5*3*7*1 = 6615 and product = 6615
# The product of 9*7*5*7*1*3 = 6615 and product = 6615
# The product of 9*7*5*7*3*1 = 6615 and product = 6615
# The product of 9*7*7*1*3*5 = 6615 and product = 6615
# The product of 9*7*7*1*5*3 = 6615 and product = 6615
# The product of 9*7*7*3*1*5 = 6615 and product = 6615
# The product of 9*7*7*3*5*1 = 6615 and product = 6615
# The product of 9*7*7*5*1*3 = 6615 and product = 6615
# The product of 9*7*7*5*3*1 = 6615 and product = 6615
# The product of 1*3*8*8*9*9 = 15552 and product = 15552
# The product of 1*3*8*9*8*9 = 15552 and product = 15552
# The product of 1*3*8*9*9*8 = 15552 and product = 15552
# The product of 1*3*9*8*8*9 = 15552 and product = 15552
# The product of 1*3*9*8*9*8 = 15552 and product = 15552
# The product of 1*3*9*9*8*8 = 15552 and product = 15552
# The product of 1*4*6*8*9*9 = 15552 and product = 15552
# The product of 1*4*6*9*8*9 = 15552 and product = 15552
# The product of 1*4*6*9*9*8 = 15552 and product = 15552
# The product of 1*4*8*6*9*9 = 15552 and product = 15552
# The product of 1*4*8*9*6*9 = 15552 and product = 15552
# The product of 1*4*8*9*9*6 = 15552 and product = 15552
# The product of 1*4*9*6*8*9 = 15552 and product = 15552
# The product of 1*4*9*6*9*8 = 15552 and product = 15552
# The product of 1*4*9*8*6*9 = 15552 and product = 15552
# The product of 1*4*9*8*9*6 = 15552 and product = 15552
# The product of 1*4*9*9*6*8 = 15552 and product = 15552
# The product of 1*4*9*9*8*6 = 15552 and product = 15552
# The product of 1*6*4*8*9*9 = 15552 and product = 15552
# The product of 1*6*4*9*8*9 = 15552 and product = 15552
# The product of 1*6*4*9*9*8 = 15552 and product = 15552
# The product of 1*6*6*6*8*9 = 15552 and product = 15552
# The product of 1*6*6*6*9*8 = 15552 and product = 15552
# The product of 1*6*6*8*6*9 = 15552 and product = 15552
# The product of 1*6*6*8*9*6 = 15552 and product = 15552
# The product of 1*6*6*9*6*8 = 15552 and product = 15552
# The product of 1*6*6*9*8*6 = 15552 and product = 15552
# The product of 1*6*8*4*9*9 = 15552 and product = 15552
# The product of 1*6*8*6*6*9 = 15552 and product = 15552
# The product of 1*6*8*6*9*6 = 15552 and product = 15552
# The product of 1*6*8*9*4*9 = 15552 and product = 15552
# The product of 1*6*8*9*6*6 = 15552 and product = 15552
# The product of 1*6*8*9*9*4 = 15552 and product = 15552
# The product of 1*6*9*4*8*9 = 15552 and product = 15552
# The product of 1*6*9*4*9*8 = 15552 and product = 15552
# The product of 1*6*9*6*6*8 = 15552 and product = 15552
# The product of 1*6*9*6*8*6 = 15552 and product = 15552
# The product of 1*6*9*8*4*9 = 15552 and product = 15552
# The product of 1*6*9*8*6*6 = 15552 and product = 15552
# The product of 1*6*9*8*9*4 = 15552 and product = 15552
# The product of 1*6*9*9*4*8 = 15552 and product = 15552
# The product of 1*6*9*9*8*4 = 15552 and product = 15552
# The product of 1*8*3*8*9*9 = 15552 and product = 15552
# The product of 1*8*3*9*8*9 = 15552 and product = 15552
# The product of 1*8*3*9*9*8 = 15552 and product = 15552
# The product of 1*8*4*6*9*9 = 15552 and product = 15552
# The product of 1*8*4*9*6*9 = 15552 and product = 15552
# The product of 1*8*4*9*9*6 = 15552 and product = 15552
# The product of 1*8*6*4*9*9 = 15552 and product = 15552
# The product of 1*8*6*6*6*9 = 15552 and product = 15552
# The product of 1*8*6*6*9*6 = 15552 and product = 15552
# The product of 1*8*6*9*4*9 = 15552 and product = 15552
# The product of 1*8*6*9*6*6 = 15552 and product = 15552
# The product of 1*8*6*9*9*4 = 15552 and product = 15552
# The product of 1*8*8*3*9*9 = 15552 and product = 15552
# The product of 1*8*8*9*3*9 = 15552 and product = 15552
# The product of 1*8*8*9*9*3 = 15552 and product = 15552
# The product of 1*8*9*3*8*9 = 15552 and product = 15552
# The product of 1*8*9*3*9*8 = 15552 and product = 15552
# The product of 1*8*9*4*6*9 = 15552 and product = 15552
# The product of 1*8*9*4*9*6 = 15552 and product = 15552
# The product of 1*8*9*6*4*9 = 15552 and product = 15552
# The product of 1*8*9*6*6*6 = 15552 and product = 15552
# The product of 1*8*9*6*9*4 = 15552 and product = 15552
# The product of 1*8*9*8*3*9 = 15552 and product = 15552
# The product of 1*8*9*8*9*3 = 15552 and product = 15552
# The product of 1*8*9*9*3*8 = 15552 and product = 15552
# The product of 1*8*9*9*4*6 = 15552 and product = 15552
# The product of 1*8*9*9*6*4 = 15552 and product = 15552
# The product of 1*8*9*9*8*3 = 15552 and product = 15552
# The product of 1*9*3*8*8*9 = 15552 and product = 15552
# The product of 1*9*3*8*9*8 = 15552 and product = 15552
# The product of 1*9*3*9*8*8 = 15552 and product = 15552
# The product of 1*9*4*6*8*9 = 15552 and product = 15552
# The product of 1*9*4*6*9*8 = 15552 and product = 15552
# The product of 1*9*4*8*6*9 = 15552 and product = 15552
# The product of 1*9*4*8*9*6 = 15552 and product = 15552
# The product of 1*9*4*9*6*8 = 15552 and product = 15552
# The product of 1*9*4*9*8*6 = 15552 and product = 15552
# The product of 1*9*6*4*8*9 = 15552 and product = 15552
# The product of 1*9*6*4*9*8 = 15552 and product = 15552
# The product of 1*9*6*6*6*8 = 15552 and product = 15552
# The product of 1*9*6*6*8*6 = 15552 and product = 15552
# The product of 1*9*6*8*4*9 = 15552 and product = 15552
# The product of 1*9*6*8*6*6 = 15552 and product = 15552
# The product of 1*9*6*8*9*4 = 15552 and product = 15552
# The product of 1*9*6*9*4*8 = 15552 and product = 15552
# The product of 1*9*6*9*8*4 = 15552 and product = 15552
# The product of 1*9*8*3*8*9 = 15552 and product = 15552
# The product of 1*9*8*3*9*8 = 15552 and product = 15552
# The product of 1*9*8*4*6*9 = 15552 and product = 15552
# The product of 1*9*8*4*9*6 = 15552 and product = 15552
# The product of 1*9*8*6*4*9 = 15552 and product = 15552
# The product of 1*9*8*6*6*6 = 15552 and product = 15552
# The product of 1*9*8*6*9*4 = 15552 and product = 15552
# The product of 1*9*8*8*3*9 = 15552 and product = 15552
# The product of 1*9*8*8*9*3 = 15552 and product = 15552
# The product of 1*9*8*9*3*8 = 15552 and product = 15552
# The product of 1*9*8*9*4*6 = 15552 and product = 15552
# The product of 1*9*8*9*6*4 = 15552 and product = 15552
# The product of 1*9*8*9*8*3 = 15552 and product = 15552
# The product of 1*9*9*3*8*8 = 15552 and product = 15552
# The product of 1*9*9*4*6*8 = 15552 and product = 15552
# The product of 1*9*9*4*8*6 = 15552 and product = 15552
# The product of 1*9*9*6*4*8 = 15552 and product = 15552
# The product of 1*9*9*6*8*4 = 15552 and product = 15552
# The product of 1*9*9*8*3*8 = 15552 and product = 15552
# The product of 1*9*9*8*4*6 = 15552 and product = 15552
# The product of 1*9*9*8*6*4 = 15552 and product = 15552
# The product of 1*9*9*8*8*3 = 15552 and product = 15552
# The product of 2*2*6*8*9*9 = 15552 and product = 15552
# The product of 2*2*6*9*8*9 = 15552 and product = 15552
# The product of 2*2*6*9*9*8 = 15552 and product = 15552
# The product of 2*2*8*6*9*9 = 15552 and product = 15552
# The product of 2*2*8*9*6*9 = 15552 and product = 15552
# The product of 2*2*8*9*9*6 = 15552 and product = 15552
# The product of 2*2*9*6*8*9 = 15552 and product = 15552
# The product of 2*2*9*6*9*8 = 15552 and product = 15552
# The product of 2*2*9*8*6*9 = 15552 and product = 15552
# The product of 2*2*9*8*9*6 = 15552 and product = 15552
# The product of 2*2*9*9*6*8 = 15552 and product = 15552
# The product of 2*2*9*9*8*6 = 15552 and product = 15552
# The product of 2*3*4*8*9*9 = 15552 and product = 15552
# The product of 2*3*4*9*8*9 = 15552 and product = 15552
# The product of 2*3*4*9*9*8 = 15552 and product = 15552
# The product of 2*3*6*6*8*9 = 15552 and product = 15552
# The product of 2*3*6*6*9*8 = 15552 and product = 15552
# The product of 2*3*6*8*6*9 = 15552 and product = 15552
# The product of 2*3*6*8*9*6 = 15552 and product = 15552
# The product of 2*3*6*9*6*8 = 15552 and product = 15552
# The product of 2*3*6*9*8*6 = 15552 and product = 15552
# The product of 2*3*8*4*9*9 = 15552 and product = 15552
# The product of 2*3*8*6*6*9 = 15552 and product = 15552
# The product of 2*3*8*6*9*6 = 15552 and product = 15552
# The product of 2*3*8*9*4*9 = 15552 and product = 15552
# The product of 2*3*8*9*6*6 = 15552 and product = 15552
# The product of 2*3*8*9*9*4 = 15552 and product = 15552
# The product of 2*3*9*4*8*9 = 15552 and product = 15552
# The product of 2*3*9*4*9*8 = 15552 and product = 15552
# The product of 2*3*9*6*6*8 = 15552 and product = 15552
# The product of 2*3*9*6*8*6 = 15552 and product = 15552
# The product of 2*3*9*8*4*9 = 15552 and product = 15552
# The product of 2*3*9*8*6*6 = 15552 and product = 15552
# The product of 2*3*9*8*9*4 = 15552 and product = 15552
# The product of 2*3*9*9*4*8 = 15552 and product = 15552
# The product of 2*3*9*9*8*4 = 15552 and product = 15552
# The product of 2*4*3*8*9*9 = 15552 and product = 15552
# The product of 2*4*3*9*8*9 = 15552 and product = 15552
# The product of 2*4*3*9*9*8 = 15552 and product = 15552
# The product of 2*4*4*6*9*9 = 15552 and product = 15552
# The product of 2*4*4*9*6*9 = 15552 and product = 15552
# The product of 2*4*4*9*9*6 = 15552 and product = 15552
# The product of 2*4*6*4*9*9 = 15552 and product = 15552
# The product of 2*4*6*6*6*9 = 15552 and product = 15552
# The product of 2*4*6*6*9*6 = 15552 and product = 15552
# The product of 2*4*6*9*4*9 = 15552 and product = 15552
# The product of 2*4*6*9*6*6 = 15552 and product = 15552
# The product of 2*4*6*9*9*4 = 15552 and product = 15552
# The product of 2*4*8*3*9*9 = 15552 and product = 15552
# The product of 2*4*8*9*3*9 = 15552 and product = 15552
# The product of 2*4*8*9*9*3 = 15552 and product = 15552
# The product of 2*4*9*3*8*9 = 15552 and product = 15552
# The product of 2*4*9*3*9*8 = 15552 and product = 15552
# The product of 2*4*9*4*6*9 = 15552 and product = 15552
# The product of 2*4*9*4*9*6 = 15552 and product = 15552
# The product of 2*4*9*6*4*9 = 15552 and product = 15552
# The product of 2*4*9*6*6*6 = 15552 and product = 15552
# The product of 2*4*9*6*9*4 = 15552 and product = 15552
# The product of 2*4*9*8*3*9 = 15552 and product = 15552
# The product of 2*4*9*8*9*3 = 15552 and product = 15552
# The product of 2*4*9*9*3*8 = 15552 and product = 15552
# The product of 2*4*9*9*4*6 = 15552 and product = 15552
# The product of 2*4*9*9*6*4 = 15552 and product = 15552
# The product of 2*4*9*9*8*3 = 15552 and product = 15552
# The product of 2*6*2*8*9*9 = 15552 and product = 15552
# The product of 2*6*2*9*8*9 = 15552 and product = 15552
# The product of 2*6*2*9*9*8 = 15552 and product = 15552
# The product of 2*6*3*6*8*9 = 15552 and product = 15552
# The product of 2*6*3*6*9*8 = 15552 and product = 15552
# The product of 2*6*3*8*6*9 = 15552 and product = 15552
# The product of 2*6*3*8*9*6 = 15552 and product = 15552
# The product of 2*6*3*9*6*8 = 15552 and product = 15552
# The product of 2*6*3*9*8*6 = 15552 and product = 15552
# The product of 2*6*4*4*9*9 = 15552 and product = 15552
# The product of 2*6*4*6*6*9 = 15552 and product = 15552
# The product of 2*6*4*6*9*6 = 15552 and product = 15552
# The product of 2*6*4*9*4*9 = 15552 and product = 15552
# The product of 2*6*4*9*6*6 = 15552 and product = 15552
# The product of 2*6*4*9*9*4 = 15552 and product = 15552
# The product of 2*6*6*3*8*9 = 15552 and product = 15552
# The product of 2*6*6*3*9*8 = 15552 and product = 15552
# The product of 2*6*6*4*6*9 = 15552 and product = 15552
# The product of 2*6*6*4*9*6 = 15552 and product = 15552
# The product of 2*6*6*6*4*9 = 15552 and product = 15552
# The product of 2*6*6*6*6*6 = 15552 and product = 15552
# The product of 2*6*6*6*9*4 = 15552 and product = 15552
# The product of 2*6*6*8*3*9 = 15552 and product = 15552
# The product of 2*6*6*8*9*3 = 15552 and product = 15552
# The product of 2*6*6*9*3*8 = 15552 and product = 15552
# The product of 2*6*6*9*4*6 = 15552 and product = 15552
# The product of 2*6*6*9*6*4 = 15552 and product = 15552
# The product of 2*6*6*9*8*3 = 15552 and product = 15552
# The product of 2*6*8*2*9*9 = 15552 and product = 15552
# The product of 2*6*8*3*6*9 = 15552 and product = 15552
# The product of 2*6*8*3*9*6 = 15552 and product = 15552
# The product of 2*6*8*6*3*9 = 15552 and product = 15552
# The product of 2*6*8*6*9*3 = 15552 and product = 15552
# The product of 2*6*8*9*2*9 = 15552 and product = 15552
# The product of 2*6*8*9*3*6 = 15552 and product = 15552
# The product of 2*6*8*9*6*3 = 15552 and product = 15552
# The product of 2*6*8*9*9*2 = 15552 and product = 15552
# The product of 2*6*9*2*8*9 = 15552 and product = 15552
# The product of 2*6*9*2*9*8 = 15552 and product = 15552
# The product of 2*6*9*3*6*8 = 15552 and product = 15552
# The product of 2*6*9*3*8*6 = 15552 and product = 15552
# The product of 2*6*9*4*4*9 = 15552 and product = 15552
# The product of 2*6*9*4*6*6 = 15552 and product = 15552
# The product of 2*6*9*4*9*4 = 15552 and product = 15552
# The product of 2*6*9*6*3*8 = 15552 and product = 15552
# The product of 2*6*9*6*4*6 = 15552 and product = 15552
# The product of 2*6*9*6*6*4 = 15552 and product = 15552
# The product of 2*6*9*6*8*3 = 15552 and product = 15552
# The product of 2*6*9*8*2*9 = 15552 and product = 15552
# The product of 2*6*9*8*3*6 = 15552 and product = 15552
# The product of 2*6*9*8*6*3 = 15552 and product = 15552
# The product of 2*6*9*8*9*2 = 15552 and product = 15552
# The product of 2*6*9*9*2*8 = 15552 and product = 15552
# The product of 2*6*9*9*4*4 = 15552 and product = 15552
# The product of 2*6*9*9*8*2 = 15552 and product = 15552
# The product of 2*8*2*6*9*9 = 15552 and product = 15552
# The product of 2*8*2*9*6*9 = 15552 and product = 15552
# The product of 2*8*2*9*9*6 = 15552 and product = 15552
# The product of 2*8*3*4*9*9 = 15552 and product = 15552
# The product of 2*8*3*6*6*9 = 15552 and product = 15552
# The product of 2*8*3*6*9*6 = 15552 and product = 15552
# The product of 2*8*3*9*4*9 = 15552 and product = 15552
# The product of 2*8*3*9*6*6 = 15552 and product = 15552
# The product of 2*8*3*9*9*4 = 15552 and product = 15552
# The product of 2*8*4*3*9*9 = 15552 and product = 15552
# The product of 2*8*4*9*3*9 = 15552 and product = 15552
# The product of 2*8*4*9*9*3 = 15552 and product = 15552
# The product of 2*8*6*2*9*9 = 15552 and product = 15552
# The product of 2*8*6*3*6*9 = 15552 and product = 15552
# The product of 2*8*6*3*9*6 = 15552 and product = 15552
# The product of 2*8*6*6*3*9 = 15552 and product = 15552
# The product of 2*8*6*6*9*3 = 15552 and product = 15552
# The product of 2*8*6*9*2*9 = 15552 and product = 15552
# The product of 2*8*6*9*3*6 = 15552 and product = 15552
# The product of 2*8*6*9*6*3 = 15552 and product = 15552
# The product of 2*8*6*9*9*2 = 15552 and product = 15552
# The product of 2*8*9*2*6*9 = 15552 and product = 15552
# The product of 2*8*9*2*9*6 = 15552 and product = 15552
# The product of 2*8*9*3*4*9 = 15552 and product = 15552
# The product of 2*8*9*3*6*6 = 15552 and product = 15552
# The product of 2*8*9*3*9*4 = 15552 and product = 15552
# The product of 2*8*9*4*3*9 = 15552 and product = 15552
# The product of 2*8*9*4*9*3 = 15552 and product = 15552
# The product of 2*8*9*6*2*9 = 15552 and product = 15552
# The product of 2*8*9*6*3*6 = 15552 and product = 15552
# The product of 2*8*9*6*6*3 = 15552 and product = 15552
# The product of 2*8*9*6*9*2 = 15552 and product = 15552
# The product of 2*8*9*9*2*6 = 15552 and product = 15552
# The product of 2*8*9*9*3*4 = 15552 and product = 15552
# The product of 2*8*9*9*4*3 = 15552 and product = 15552
# The product of 2*8*9*9*6*2 = 15552 and product = 15552
# The product of 2*9*2*6*8*9 = 15552 and product = 15552
# The product of 2*9*2*6*9*8 = 15552 and product = 15552
# The product of 2*9*2*8*6*9 = 15552 and product = 15552
# The product of 2*9*2*8*9*6 = 15552 and product = 15552
# The product of 2*9*2*9*6*8 = 15552 and product = 15552
# The product of 2*9*2*9*8*6 = 15552 and product = 15552
# The product of 2*9*3*4*8*9 = 15552 and product = 15552
# The product of 2*9*3*4*9*8 = 15552 and product = 15552
# The product of 2*9*3*6*6*8 = 15552 and product = 15552
# The product of 2*9*3*6*8*6 = 15552 and product = 15552
# The product of 2*9*3*8*4*9 = 15552 and product = 15552
# The product of 2*9*3*8*6*6 = 15552 and product = 15552
# The product of 2*9*3*8*9*4 = 15552 and product = 15552
# The product of 2*9*3*9*4*8 = 15552 and product = 15552
# The product of 2*9*3*9*8*4 = 15552 and product = 15552
# The product of 2*9*4*3*8*9 = 15552 and product = 15552
# The product of 2*9*4*3*9*8 = 15552 and product = 15552
# The product of 2*9*4*4*6*9 = 15552 and product = 15552
# The product of 2*9*4*4*9*6 = 15552 and product = 15552
# The product of 2*9*4*6*4*9 = 15552 and product = 15552
# The product of 2*9*4*6*6*6 = 15552 and product = 15552
# The product of 2*9*4*6*9*4 = 15552 and product = 15552
# The product of 2*9*4*8*3*9 = 15552 and product = 15552
# The product of 2*9*4*8*9*3 = 15552 and product = 15552
# The product of 2*9*4*9*3*8 = 15552 and product = 15552
# The product of 2*9*4*9*4*6 = 15552 and product = 15552
# The product of 2*9*4*9*6*4 = 15552 and product = 15552
# The product of 2*9*4*9*8*3 = 15552 and product = 15552
# The product of 2*9*6*2*8*9 = 15552 and product = 15552
# The product of 2*9*6*2*9*8 = 15552 and product = 15552
# The product of 2*9*6*3*6*8 = 15552 and product = 15552
# The product of 2*9*6*3*8*6 = 15552 and product = 15552
# The product of 2*9*6*4*4*9 = 15552 and product = 15552
# The product of 2*9*6*4*6*6 = 15552 and product = 15552
# The product of 2*9*6*4*9*4 = 15552 and product = 15552
# The product of 2*9*6*6*3*8 = 15552 and product = 15552
# The product of 2*9*6*6*4*6 = 15552 and product = 15552
# The product of 2*9*6*6*6*4 = 15552 and product = 15552
# The product of 2*9*6*6*8*3 = 15552 and product = 15552
# The product of 2*9*6*8*2*9 = 15552 and product = 15552
# The product of 2*9*6*8*3*6 = 15552 and product = 15552
# The product of 2*9*6*8*6*3 = 15552 and product = 15552
# The product of 2*9*6*8*9*2 = 15552 and product = 15552
# The product of 2*9*6*9*2*8 = 15552 and product = 15552
# The product of 2*9*6*9*4*4 = 15552 and product = 15552
# The product of 2*9*6*9*8*2 = 15552 and product = 15552
# The product of 2*9*8*2*6*9 = 15552 and product = 15552
# The product of 2*9*8*2*9*6 = 15552 and product = 15552
# The product of 2*9*8*3*4*9 = 15552 and product = 15552
# The product of 2*9*8*3*6*6 = 15552 and product = 15552
# The product of 2*9*8*3*9*4 = 15552 and product = 15552
# The product of 2*9*8*4*3*9 = 15552 and product = 15552
# The product of 2*9*8*4*9*3 = 15552 and product = 15552
# The product of 2*9*8*6*2*9 = 15552 and product = 15552
# The product of 2*9*8*6*3*6 = 15552 and product = 15552
# The product of 2*9*8*6*6*3 = 15552 and product = 15552
# The product of 2*9*8*6*9*2 = 15552 and product = 15552
# The product of 2*9*8*9*2*6 = 15552 and product = 15552
# The product of 2*9*8*9*3*4 = 15552 and product = 15552
# The product of 2*9*8*9*4*3 = 15552 and product = 15552
# The product of 2*9*8*9*6*2 = 15552 and product = 15552
# The product of 2*9*9*2*6*8 = 15552 and product = 15552
# The product of 2*9*9*2*8*6 = 15552 and product = 15552
# The product of 2*9*9*3*4*8 = 15552 and product = 15552
# The product of 2*9*9*3*8*4 = 15552 and product = 15552
# The product of 2*9*9*4*3*8 = 15552 and product = 15552
# The product of 2*9*9*4*4*6 = 15552 and product = 15552
# The product of 2*9*9*4*6*4 = 15552 and product = 15552
# The product of 2*9*9*4*8*3 = 15552 and product = 15552
# The product of 2*9*9*6*2*8 = 15552 and product = 15552
# The product of 2*9*9*6*4*4 = 15552 and product = 15552
# The product of 2*9*9*6*8*2 = 15552 and product = 15552
# The product of 2*9*9*8*2*6 = 15552 and product = 15552
# The product of 2*9*9*8*3*4 = 15552 and product = 15552
# The product of 2*9*9*8*4*3 = 15552 and product = 15552
# The product of 2*9*9*8*6*2 = 15552 and product = 15552
# The product of 3*1*8*8*9*9 = 15552 and product = 15552
# The product of 3*1*8*9*8*9 = 15552 and product = 15552
# The product of 3*1*8*9*9*8 = 15552 and product = 15552
# The product of 3*1*9*8*8*9 = 15552 and product = 15552
# The product of 3*1*9*8*9*8 = 15552 and product = 15552
# The product of 3*1*9*9*8*8 = 15552 and product = 15552
# The product of 3*2*4*8*9*9 = 15552 and product = 15552
# The product of 3*2*4*9*8*9 = 15552 and product = 15552
# The product of 3*2*4*9*9*8 = 15552 and product = 15552
# The product of 3*2*6*6*8*9 = 15552 and product = 15552
# The product of 3*2*6*6*9*8 = 15552 and product = 15552
# The product of 3*2*6*8*6*9 = 15552 and product = 15552
# The product of 3*2*6*8*9*6 = 15552 and product = 15552
# The product of 3*2*6*9*6*8 = 15552 and product = 15552
# The product of 3*2*6*9*8*6 = 15552 and product = 15552
# The product of 3*2*8*4*9*9 = 15552 and product = 15552
# The product of 3*2*8*6*6*9 = 15552 and product = 15552
# The product of 3*2*8*6*9*6 = 15552 and product = 15552
# The product of 3*2*8*9*4*9 = 15552 and product = 15552
# The product of 3*2*8*9*6*6 = 15552 and product = 15552
# The product of 3*2*8*9*9*4 = 15552 and product = 15552
# The product of 3*2*9*4*8*9 = 15552 and product = 15552
# The product of 3*2*9*4*9*8 = 15552 and product = 15552
# The product of 3*2*9*6*6*8 = 15552 and product = 15552
# The product of 3*2*9*6*8*6 = 15552 and product = 15552
# The product of 3*2*9*8*4*9 = 15552 and product = 15552
# The product of 3*2*9*8*6*6 = 15552 and product = 15552
# The product of 3*2*9*8*9*4 = 15552 and product = 15552
# The product of 3*2*9*9*4*8 = 15552 and product = 15552
# The product of 3*2*9*9*8*4 = 15552 and product = 15552
# The product of 3*3*3*8*8*9 = 15552 and product = 15552
# The product of 3*3*3*8*9*8 = 15552 and product = 15552
# The product of 3*3*3*9*8*8 = 15552 and product = 15552
# The product of 3*3*4*6*8*9 = 15552 and product = 15552
# The product of 3*3*4*6*9*8 = 15552 and product = 15552
# The product of 3*3*4*8*6*9 = 15552 and product = 15552
# The product of 3*3*4*8*9*6 = 15552 and product = 15552
# The product of 3*3*4*9*6*8 = 15552 and product = 15552
# The product of 3*3*4*9*8*6 = 15552 and product = 15552
# The product of 3*3*6*4*8*9 = 15552 and product = 15552
# The product of 3*3*6*4*9*8 = 15552 and product = 15552
# The product of 3*3*6*6*6*8 = 15552 and product = 15552
# The product of 3*3*6*6*8*6 = 15552 and product = 15552
# The product of 3*3*6*8*4*9 = 15552 and product = 15552
# The product of 3*3*6*8*6*6 = 15552 and product = 15552
# The product of 3*3*6*8*9*4 = 15552 and product = 15552
# The product of 3*3*6*9*4*8 = 15552 and product = 15552
# The product of 3*3*6*9*8*4 = 15552 and product = 15552
# The product of 3*3*8*3*8*9 = 15552 and product = 15552
# The product of 3*3*8*3*9*8 = 15552 and product = 15552
# The product of 3*3*8*4*6*9 = 15552 and product = 15552
# The product of 3*3*8*4*9*6 = 15552 and product = 15552
# The product of 3*3*8*6*4*9 = 15552 and product = 15552
# The product of 3*3*8*6*6*6 = 15552 and product = 15552
# The product of 3*3*8*6*9*4 = 15552 and product = 15552
# The product of 3*3*8*8*3*9 = 15552 and product = 15552
# The product of 3*3*8*8*9*3 = 15552 and product = 15552
# The product of 3*3*8*9*3*8 = 15552 and product = 15552
# The product of 3*3*8*9*4*6 = 15552 and product = 15552
# The product of 3*3*8*9*6*4 = 15552 and product = 15552
# The product of 3*3*8*9*8*3 = 15552 and product = 15552
# The product of 3*3*9*3*8*8 = 15552 and product = 15552
# The product of 3*3*9*4*6*8 = 15552 and product = 15552
# The product of 3*3*9*4*8*6 = 15552 and product = 15552
# The product of 3*3*9*6*4*8 = 15552 and product = 15552
# The product of 3*3*9*6*8*4 = 15552 and product = 15552
# The product of 3*3*9*8*3*8 = 15552 and product = 15552
# The product of 3*3*9*8*4*6 = 15552 and product = 15552
# The product of 3*3*9*8*6*4 = 15552 and product = 15552
# The product of 3*3*9*8*8*3 = 15552 and product = 15552
# The product of 3*4*2*8*9*9 = 15552 and product = 15552
# The product of 3*4*2*9*8*9 = 15552 and product = 15552
# The product of 3*4*2*9*9*8 = 15552 and product = 15552
# The product of 3*4*3*6*8*9 = 15552 and product = 15552
# The product of 3*4*3*6*9*8 = 15552 and product = 15552
# The product of 3*4*3*8*6*9 = 15552 and product = 15552
# The product of 3*4*3*8*9*6 = 15552 and product = 15552
# The product of 3*4*3*9*6*8 = 15552 and product = 15552
# The product of 3*4*3*9*8*6 = 15552 and product = 15552
# The product of 3*4*4*4*9*9 = 15552 and product = 15552
# The product of 3*4*4*6*6*9 = 15552 and product = 15552
# The product of 3*4*4*6*9*6 = 15552 and product = 15552
# The product of 3*4*4*9*4*9 = 15552 and product = 15552
# The product of 3*4*4*9*6*6 = 15552 and product = 15552
# The product of 3*4*4*9*9*4 = 15552 and product = 15552
# The product of 3*4*6*3*8*9 = 15552 and product = 15552
# The product of 3*4*6*3*9*8 = 15552 and product = 15552
# The product of 3*4*6*4*6*9 = 15552 and product = 15552
# The product of 3*4*6*4*9*6 = 15552 and product = 15552
# The product of 3*4*6*6*4*9 = 15552 and product = 15552
# The product of 3*4*6*6*6*6 = 15552 and product = 15552
# The product of 3*4*6*6*9*4 = 15552 and product = 15552
# The product of 3*4*6*8*3*9 = 15552 and product = 15552
# The product of 3*4*6*8*9*3 = 15552 and product = 15552
# The product of 3*4*6*9*3*8 = 15552 and product = 15552
# The product of 3*4*6*9*4*6 = 15552 and product = 15552
# The product of 3*4*6*9*6*4 = 15552 and product = 15552
# The product of 3*4*6*9*8*3 = 15552 and product = 15552
# The product of 3*4*8*2*9*9 = 15552 and product = 15552
# The product of 3*4*8*3*6*9 = 15552 and product = 15552
# The product of 3*4*8*3*9*6 = 15552 and product = 15552
# The product of 3*4*8*6*3*9 = 15552 and product = 15552
# The product of 3*4*8*6*9*3 = 15552 and product = 15552
# The product of 3*4*8*9*2*9 = 15552 and product = 15552
# The product of 3*4*8*9*3*6 = 15552 and product = 15552
# The product of 3*4*8*9*6*3 = 15552 and product = 15552
# The product of 3*4*8*9*9*2 = 15552 and product = 15552
# The product of 3*4*9*2*8*9 = 15552 and product = 15552
# The product of 3*4*9*2*9*8 = 15552 and product = 15552
# The product of 3*4*9*3*6*8 = 15552 and product = 15552
# The product of 3*4*9*3*8*6 = 15552 and product = 15552
# The product of 3*4*9*4*4*9 = 15552 and product = 15552
# The product of 3*4*9*4*6*6 = 15552 and product = 15552
# The product of 3*4*9*4*9*4 = 15552 and product = 15552
# The product of 3*4*9*6*3*8 = 15552 and product = 15552
# The product of 3*4*9*6*4*6 = 15552 and product = 15552
# The product of 3*4*9*6*6*4 = 15552 and product = 15552
# The product of 3*4*9*6*8*3 = 15552 and product = 15552
# The product of 3*4*9*8*2*9 = 15552 and product = 15552
# The product of 3*4*9*8*3*6 = 15552 and product = 15552
# The product of 3*4*9*8*6*3 = 15552 and product = 15552
# The product of 3*4*9*8*9*2 = 15552 and product = 15552
# The product of 3*4*9*9*2*8 = 15552 and product = 15552
# The product of 3*4*9*9*4*4 = 15552 and product = 15552
# The product of 3*4*9*9*8*2 = 15552 and product = 15552
# The product of 3*6*2*6*8*9 = 15552 and product = 15552
# The product of 3*6*2*6*9*8 = 15552 and product = 15552
# ...
# The product of 5*3*4*1*1*7 = 420 and product = 420
# The product of 5*3*4*1*7*1 = 420 and product = 420
# The product of 5*3*4*7*1*1 = 420 and product = 420
# The product of 5*3*7*1*1*4 = 420 and product = 420
# The product of 5*3*7*1*2*2 = 420 and product = 420
# The product of 5*3*7*1*4*1 = 420 and product = 420
# The product of 5*3*7*2*1*2 = 420 and product = 420
# The product of 5*3*7*2*2*1 = 420 and product = 420
# The product of 5*3*7*4*1*1 = 420 and product = 420
# The product of 5*4*1*1*3*7 = 420 and product = 420
# The product of 5*4*1*1*7*3 = 420 and product = 420
# The product of 5*4*1*3*1*7 = 420 and product = 420
# The product of 5*4*1*3*7*1 = 420 and product = 420
# The product of 5*4*1*7*1*3 = 420 and product = 420
# The product of 5*4*1*7*3*1 = 420 and product = 420
# The product of 5*4*3*1*1*7 = 420 and product = 420
# The product of 5*4*3*1*7*1 = 420 and product = 420
# The product of 5*4*3*7*1*1 = 420 and product = 420
# The product of 5*4*7*1*1*3 = 420 and product = 420
# The product of 5*4*7*1*3*1 = 420 and product = 420
# The product of 5*4*7*3*1*1 = 420 and product = 420
# The product of 5*6*1*1*2*7 = 420 and product = 420
# The product of 5*6*1*1*7*2 = 420 and product = 420
# The product of 5*6*1*2*1*7 = 420 and product = 420
# The product of 5*6*1*2*7*1 = 420 and product = 420
# The product of 5*6*1*7*1*2 = 420 and product = 420
# The product of 5*6*1*7*2*1 = 420 and product = 420
# The product of 5*6*2*1*1*7 = 420 and product = 420
# The product of 5*6*2*1*7*1 = 420 and product = 420
# The product of 5*6*2*7*1*1 = 420 and product = 420
# The product of 5*6*7*1*1*2 = 420 and product = 420
# The product of 5*6*7*1*2*1 = 420 and product = 420
# The product of 5*6*7*2*1*1 = 420 and product = 420
# The product of 5*7*1*1*2*6 = 420 and product = 420
# The product of 5*7*1*1*3*4 = 420 and product = 420
# The product of 5*7*1*1*4*3 = 420 and product = 420
# The product of 5*7*1*1*6*2 = 420 and product = 420
# The product of 5*7*1*2*1*6 = 420 and product = 420
# The product of 5*7*1*2*2*3 = 420 and product = 420
# The product of 5*7*1*2*3*2 = 420 and product = 420
# The product of 5*7*1*2*6*1 = 420 and product = 420
# The product of 5*7*1*3*1*4 = 420 and product = 420
# The product of 5*7*1*3*2*2 = 420 and product = 420
# The product of 5*7*1*3*4*1 = 420 and product = 420
# The product of 5*7*1*4*1*3 = 420 and product = 420
# The product of 5*7*1*4*3*1 = 420 and product = 420
# The product of 5*7*1*6*1*2 = 420 and product = 420
# The product of 5*7*1*6*2*1 = 420 and product = 420
# The product of 5*7*2*1*1*6 = 420 and product = 420
# The product of 5*7*2*1*2*3 = 420 and product = 420
# The product of 5*7*2*1*3*2 = 420 and product = 420
# The product of 5*7*2*1*6*1 = 420 and product = 420
# The product of 5*7*2*2*1*3 = 420 and product = 420
# The product of 5*7*2*2*3*1 = 420 and product = 420
# The product of 5*7*2*3*1*2 = 420 and product = 420
# The product of 5*7*2*3*2*1 = 420 and product = 420
# The product of 5*7*2*6*1*1 = 420 and product = 420
# The product of 5*7*3*1*1*4 = 420 and product = 420
# The product of 5*7*3*1*2*2 = 420 and product = 420
# The product of 5*7*3*1*4*1 = 420 and product = 420
# The product of 5*7*3*2*1*2 = 420 and product = 420
# The product of 5*7*3*2*2*1 = 420 and product = 420
# The product of 5*7*3*4*1*1 = 420 and product = 420
# The product of 5*7*4*1*1*3 = 420 and product = 420
# The product of 5*7*4*1*3*1 = 420 and product = 420
# The product of 5*7*4*3*1*1 = 420 and product = 420
# The product of 5*7*6*1*1*2 = 420 and product = 420
# The product of 5*7*6*1*2*1 = 420 and product = 420
# The product of 5*7*6*2*1*1 = 420 and product = 420
# The product of 6*1*1*2*5*7 = 420 and product = 420
# The product of 6*1*1*2*7*5 = 420 and product = 420
# The product of 6*1*1*5*2*7 = 420 and product = 420
# The product of 6*1*1*5*7*2 = 420 and product = 420
# The product of 6*1*1*7*2*5 = 420 and product = 420
# The product of 6*1*1*7*5*2 = 420 and product = 420
# The product of 6*1*2*1*5*7 = 420 and product = 420
# The product of 6*1*2*1*7*5 = 420 and product = 420
# The product of 6*1*2*5*1*7 = 420 and product = 420
# The product of 6*1*2*5*7*1 = 420 and product = 420
# The product of 6*1*2*7*1*5 = 420 and product = 420
# The product of 6*1*2*7*5*1 = 420 and product = 420
# The product of 6*1*5*1*2*7 = 420 and product = 420
# The product of 6*1*5*1*7*2 = 420 and product = 420
# The product of 6*1*5*2*1*7 = 420 and product = 420
# The product of 6*1*5*2*7*1 = 420 and product = 420
# The product of 6*1*5*7*1*2 = 420 and product = 420
# The product of 6*1*5*7*2*1 = 420 and product = 420
# The product of 6*1*7*1*2*5 = 420 and product = 420
# The product of 6*1*7*1*5*2 = 420 and product = 420
# The product of 6*1*7*2*1*5 = 420 and product = 420
# The product of 6*1*7*2*5*1 = 420 and product = 420
# The product of 6*1*7*5*1*2 = 420 and product = 420
# The product of 6*1*7*5*2*1 = 420 and product = 420
# The product of 6*2*1*1*5*7 = 420 and product = 420
# The product of 6*2*1*1*7*5 = 420 and product = 420
# The product of 6*2*1*5*1*7 = 420 and product = 420
# The product of 6*2*1*5*7*1 = 420 and product = 420
# The product of 6*2*1*7*1*5 = 420 and product = 420
# The product of 6*2*1*7*5*1 = 420 and product = 420
# The product of 6*2*5*1*1*7 = 420 and product = 420
# The product of 6*2*5*1*7*1 = 420 and product = 420
# The product of 6*2*5*7*1*1 = 420 and product = 420
# The product of 6*2*7*1*1*5 = 420 and product = 420
# The product of 6*2*7*1*5*1 = 420 and product = 420
# The product of 6*2*7*5*1*1 = 420 and product = 420
# The product of 6*5*1*1*2*7 = 420 and product = 420
# The product of 6*5*1*1*7*2 = 420 and product = 420
# The product of 6*5*1*2*1*7 = 420 and product = 420
# The product of 6*5*1*2*7*1 = 420 and product = 420
# The product of 6*5*1*7*1*2 = 420 and product = 420
# The product of 6*5*1*7*2*1 = 420 and product = 420
# The product of 6*5*2*1*1*7 = 420 and product = 420
# The product of 6*5*2*1*7*1 = 420 and product = 420
# The product of 6*5*2*7*1*1 = 420 and product = 420
# The product of 6*5*7*1*1*2 = 420 and product = 420
# The product of 6*5*7*1*2*1 = 420 and product = 420
# The product of 6*5*7*2*1*1 = 420 and product = 420
# The product of 6*7*1*1*2*5 = 420 and product = 420
# The product of 6*7*1*1*5*2 = 420 and product = 420
# The product of 6*7*1*2*1*5 = 420 and product = 420
# The product of 6*7*1*2*5*1 = 420 and product = 420
# The product of 6*7*1*5*1*2 = 420 and product = 420
# The product of 6*7*1*5*2*1 = 420 and product = 420
# The product of 6*7*2*1*1*5 = 420 and product = 420
# The product of 6*7*2*1*5*1 = 420 and product = 420
# The product of 6*7*2*5*1*1 = 420 and product = 420
# The product of 6*7*5*1*1*2 = 420 and product = 420
# The product of 6*7*5*1*2*1 = 420 and product = 420
# The product of 6*7*5*2*1*1 = 420 and product = 420
# The product of 7*1*1*2*5*6 = 420 and product = 420
# The product of 7*1*1*2*6*5 = 420 and product = 420
# The product of 7*1*1*3*4*5 = 420 and product = 420
# The product of 7*1*1*3*5*4 = 420 and product = 420
# The product of 7*1*1*4*3*5 = 420 and product = 420
# The product of 7*1*1*4*5*3 = 420 and product = 420
# The product of 7*1*1*5*2*6 = 420 and product = 420
# The product of 7*1*1*5*3*4 = 420 and product = 420
# The product of 7*1*1*5*4*3 = 420 and product = 420
# The product of 7*1*1*5*6*2 = 420 and product = 420
# The product of 7*1*1*6*2*5 = 420 and product = 420
# The product of 7*1*1*6*5*2 = 420 and product = 420
# The product of 7*1*2*1*5*6 = 420 and product = 420
# The product of 7*1*2*1*6*5 = 420 and product = 420
# The product of 7*1*2*2*3*5 = 420 and product = 420
# The product of 7*1*2*2*5*3 = 420 and product = 420
# The product of 7*1*2*3*2*5 = 420 and product = 420
# The product of 7*1*2*3*5*2 = 420 and product = 420
# The product of 7*1*2*5*1*6 = 420 and product = 420
# The product of 7*1*2*5*2*3 = 420 and product = 420
# The product of 7*1*2*5*3*2 = 420 and product = 420
# The product of 7*1*2*5*6*1 = 420 and product = 420
# The product of 7*1*2*6*1*5 = 420 and product = 420
# The product of 7*1*2*6*5*1 = 420 and product = 420
# The product of 7*1*3*1*4*5 = 420 and product = 420
# The product of 7*1*3*1*5*4 = 420 and product = 420
# The product of 7*1*3*2*2*5 = 420 and product = 420
# The product of 7*1*3*2*5*2 = 420 and product = 420
# The product of 7*1*3*4*1*5 = 420 and product = 420
# The product of 7*1*3*4*5*1 = 420 and product = 420
# The product of 7*1*3*5*1*4 = 420 and product = 420
# The product of 7*1*3*5*2*2 = 420 and product = 420
# The product of 7*1*3*5*4*1 = 420 and product = 420
# The product of 7*1*4*1*3*5 = 420 and product = 420
# The product of 7*1*4*1*5*3 = 420 and product = 420
# The product of 7*1*4*3*1*5 = 420 and product = 420
# The product of 7*1*4*3*5*1 = 420 and product = 420
# The product of 7*1*4*5*1*3 = 420 and product = 420
# The product of 7*1*4*5*3*1 = 420 and product = 420
# The product of 7*1*5*1*2*6 = 420 and product = 420
# The product of 7*1*5*1*3*4 = 420 and product = 420
# The product of 7*1*5*1*4*3 = 420 and product = 420
# The product of 7*1*5*1*6*2 = 420 and product = 420
# The product of 7*1*5*2*1*6 = 420 and product = 420
# The product of 7*1*5*2*2*3 = 420 and product = 420
# The product of 7*1*5*2*3*2 = 420 and product = 420
# The product of 7*1*5*2*6*1 = 420 and product = 420
# The product of 7*1*5*3*1*4 = 420 and product = 420
# The product of 7*1*5*3*2*2 = 420 and product = 420
# The product of 7*1*5*3*4*1 = 420 and product = 420
# The product of 7*1*5*4*1*3 = 420 and product = 420
# The product of 7*1*5*4*3*1 = 420 and product = 420
# The product of 7*1*5*6*1*2 = 420 and product = 420
# The product of 7*1*5*6*2*1 = 420 and product = 420
# The product of 7*1*6*1*2*5 = 420 and product = 420
# The product of 7*1*6*1*5*2 = 420 and product = 420
# The product of 7*1*6*2*1*5 = 420 and product = 420
# The product of 7*1*6*2*5*1 = 420 and product = 420
# The product of 7*1*6*5*1*2 = 420 and product = 420
# The product of 7*1*6*5*2*1 = 420 and product = 420
# The product of 7*2*1*1*5*6 = 420 and product = 420
# The product of 7*2*1*1*6*5 = 420 and product = 420
# The product of 7*2*1*2*3*5 = 420 and product = 420
# The product of 7*2*1*2*5*3 = 420 and product = 420
# The product of 7*2*1*3*2*5 = 420 and product = 420
# The product of 7*2*1*3*5*2 = 420 and product = 420
# The product of 7*2*1*5*1*6 = 420 and product = 420
# The product of 7*2*1*5*2*3 = 420 and product = 420
# The product of 7*2*1*5*3*2 = 420 and product = 420
# The product of 7*2*1*5*6*1 = 420 and product = 420
# The product of 7*2*1*6*1*5 = 420 and product = 420
# The product of 7*2*1*6*5*1 = 420 and product = 420
# The product of 7*2*2*1*3*5 = 420 and product = 420
# The product of 7*2*2*1*5*3 = 420 and product = 420
# The product of 7*2*2*3*1*5 = 420 and product = 420
# The product of 7*2*2*3*5*1 = 420 and product = 420
# The product of 7*2*2*5*1*3 = 420 and product = 420
# The product of 7*2*2*5*3*1 = 420 and product = 420
# The product of 7*2*3*1*2*5 = 420 and product = 420
# The product of 7*2*3*1*5*2 = 420 and product = 420
# The product of 7*2*3*2*1*5 = 420 and product = 420
# The product of 7*2*3*2*5*1 = 420 and product = 420
# The product of 7*2*3*5*1*2 = 420 and product = 420
# The product of 7*2*3*5*2*1 = 420 and product = 420
# The product of 7*2*5*1*1*6 = 420 and product = 420
# The product of 7*2*5*1*2*3 = 420 and product = 420
# The product of 7*2*5*1*3*2 = 420 and product = 420
# The product of 7*2*5*1*6*1 = 420 and product = 420
# The product of 7*2*5*2*1*3 = 420 and product = 420
# The product of 7*2*5*2*3*1 = 420 and product = 420
# The product of 7*2*5*3*1*2 = 420 and product = 420
# The product of 7*2*5*3*2*1 = 420 and product = 420
# The product of 7*2*5*6*1*1 = 420 and product = 420
# The product of 7*2*6*1*1*5 = 420 and product = 420
# The product of 7*2*6*1*5*1 = 420 and product = 420
# The product of 7*2*6*5*1*1 = 420 and product = 420
# The product of 7*3*1*1*4*5 = 420 and product = 420
# The product of 7*3*1*1*5*4 = 420 and product = 420
# The product of 7*3*1*2*2*5 = 420 and product = 420
# The product of 7*3*1*2*5*2 = 420 and product = 420
# The product of 7*3*1*4*1*5 = 420 and product = 420
# The product of 7*3*1*4*5*1 = 420 and product = 420
# The product of 7*3*1*5*1*4 = 420 and product = 420
# The product of 7*3*1*5*2*2 = 420 and product = 420
# The product of 7*3*1*5*4*1 = 420 and product = 420
# The product of 7*3*2*1*2*5 = 420 and product = 420
# The product of 7*3*2*1*5*2 = 420 and product = 420
# The product of 7*3*2*2*1*5 = 420 and product = 420
# The product of 7*3*2*2*5*1 = 420 and product = 420
# The product of 7*3*2*5*1*2 = 420 and product = 420
# The product of 7*3*2*5*2*1 = 420 and product = 420
# The product of 7*3*4*1*1*5 = 420 and product = 420
# The product of 7*3*4*1*5*1 = 420 and product = 420
# The product of 7*3*4*5*1*1 = 420 and product = 420
# The product of 7*3*5*1*1*4 = 420 and product = 420
# The product of 7*3*5*1*2*2 = 420 and product = 420
# The product of 7*3*5*1*4*1 = 420 and product = 420
# The product of 7*3*5*2*1*2 = 420 and product = 420
# The product of 7*3*5*2*2*1 = 420 and product = 420
# The product of 7*3*5*4*1*1 = 420 and product = 420
# The product of 7*4*1*1*3*5 = 420 and product = 420
# The product of 7*4*1*1*5*3 = 420 and product = 420
# The product of 7*4*1*3*1*5 = 420 and product = 420
# The product of 7*4*1*3*5*1 = 420 and product = 420
# The product of 7*4*1*5*1*3 = 420 and product = 420
# The product of 7*4*1*5*3*1 = 420 and product = 420
# The product of 7*4*3*1*1*5 = 420 and product = 420
# The product of 7*4*3*1*5*1 = 420 and product = 420
# The product of 7*4*3*5*1*1 = 420 and product = 420
# The product of 7*4*5*1*1*3 = 420 and product = 420
# The product of 7*4*5*1*3*1 = 420 and product = 420
# The product of 7*4*5*3*1*1 = 420 and product = 420
# The product of 7*5*1*1*2*6 = 420 and product = 420
# The product of 7*5*1*1*3*4 = 420 and product = 420
# The product of 7*5*1*1*4*3 = 420 and product = 420
# The product of 7*5*1*1*6*2 = 420 and product = 420
# The product of 7*5*1*2*1*6 = 420 and product = 420
# The product of 7*5*1*2*2*3 = 420 and product = 420
# The product of 7*5*1*2*3*2 = 420 and product = 420
# The product of 7*5*1*2*6*1 = 420 and product = 420
# The product of 7*5*1*3*1*4 = 420 and product = 420
# The product of 7*5*1*3*2*2 = 420 and product = 420
# The product of 7*5*1*3*4*1 = 420 and product = 420
# The product of 7*5*1*4*1*3 = 420 and product = 420
# The product of 7*5*1*4*3*1 = 420 and product = 420
# The product of 7*5*1*6*1*2 = 420 and product = 420
# The product of 7*5*1*6*2*1 = 420 and product = 420
# The product of 7*5*2*1*1*6 = 420 and product = 420
# The product of 7*5*2*1*2*3 = 420 and product = 420
# The product of 7*5*2*1*3*2 = 420 and product = 420
# The product of 7*5*2*1*6*1 = 420 and product = 420
# The product of 7*5*2*2*1*3 = 420 and product = 420
# The product of 7*5*2*2*3*1 = 420 and product = 420
# The product of 7*5*2*3*1*2 = 420 and product = 420
# The product of 7*5*2*3*2*1 = 420 and product = 420
# The product of 7*5*2*6*1*1 = 420 and product = 420
# The product of 7*5*3*1*1*4 = 420 and product = 420
# The product of 7*5*3*1*2*2 = 420 and product = 420
# The product of 7*5*3*1*4*1 = 420 and product = 420
# The product of 7*5*3*2*1*2 = 420 and product = 420
# The product of 7*5*3*2*2*1 = 420 and product = 420
# The product of 7*5*3*4*1*1 = 420 and product = 420
# The product of 7*5*4*1*1*3 = 420 and product = 420
# The product of 7*5*4*1*3*1 = 420 and product = 420
# The product of 7*5*4*3*1*1 = 420 and product = 420
# The product of 7*5*6*1*1*2 = 420 and product = 420
# The product of 7*5*6*1*2*1 = 420 and product = 420
# The product of 7*5*6*2*1*1 = 420 and product = 420
# The product of 7*6*1*1*2*5 = 420 and product = 420
# The product of 7*6*1*1*5*2 = 420 and product = 420
# The product of 7*6*1*2*1*5 = 420 and product = 420
# The product of 7*6*1*2*5*1 = 420 and product = 420
# The product of 7*6*1*5*1*2 = 420 and product = 420
# The product of 7*6*1*5*2*1 = 420 and product = 420
# The product of 7*6*2*1*1*5 = 420 and product = 420
# The product of 7*6*2*1*5*1 = 420 and product = 420
# The product of 7*6*2*5*1*1 = 420 and product = 420
# The product of 7*6*5*1*1*2 = 420 and product = 420
# The product of 7*6*5*1*2*1 = 420 and product = 420
# The product of 7*6*5*2*1*1 = 420 and product = 420
#    a  b  c  d  e  f  product     p
# 0  1  3  5  7  7  9     6615  6615
# 1  1  3  5  7  9  7     6615  6615
# 2  1  3  5  9  7  7     6615  6615
# 3  1  3  7  5  7  9     6615  6615
# 4  1  3  7  5  9  7     6615  6615

# %%
# Find which numbers make the vertical products evaluate to a non-integer

qdict = []

for p in products:
    for l in range(1,10):
        quotient = p/l
        if not int(quotient) == quotient and isinstance(quotient, float):
            print("The quotient of {}/{} = {} and dividend = {}".format(p, l, quotient, p))
            q = {'dividend':p, 'divisor':l, 'quotient':quotient, 'p':p}
            qdict.append(q)
            
qdf = pd.DataFrame(qdict, columns=['dividend', 'divisor','quotient','p'])
qdf.head()

# Middle column cannot have 3, 6, 9 and right-most column cannot have 4, 5, 8
# Out:
# The quotient of 6615/2 = 3307.5 and dividend = 6615
# The quotient of 6615/4 = 1653.75 and dividend = 6615
# The quotient of 6615/6 = 1102.5 and dividend = 6615
# The quotient of 6615/8 = 826.875 and dividend = 6615
# The quotient of 15552/5 = 3110.4 and dividend = 15552
# The quotient of 15552/7 = 2221.714285714286 and dividend = 15552
# The quotient of 420/8 = 52.5 and dividend = 420
# The quotient of 420/9 = 46.666666666666664 and dividend = 420
#    dividend  divisor  quotient      p
# 0      6615        2  3307.500   6615
# 1      6615        4  1653.750   6615
# 2      6615        6  1102.500   6615
# 3      6615        8   826.875   6615
# 4     15552        5  3110.400  15552

# %%
vdf.head()
# Out:
#    a  b  c  d  e  f  product     p
# 0  1  3  5  7  7  9     6615  6615
# 1  1  3  5  7  9  7     6615  6615
# 2  1  3  5  9  7  7     6615  6615
# 3  1  3  7  5  7  9     6615  6615
# 4  1  3  7  5  9  7     6615  6615

# %%
# Remove those rows from hdf

hdf2 = hdf.loc[~(hdf.i.isin([7,9])&hdf.j.isin([2,4,5,6,8])&hdf.k.isin([3,6,7,9]))]
print("Horizontal combinations decreased from {} to {}".format(str(len(hdf)),str(len(hdf2))))
# Out:
# Horizontal combinations decreased from 54 to 51

# %%
columns = ['a','b','c','d','e','f']

rows = 0

for c in columns:
    # print(c)
    temp = vdf.loc[(vdf['product'] == 6615) & (vdf[c].isin([2,4,6,8]))]
    rows += len(temp)
    if len(temp) > 0:
        vdf = vdf.loc[~((vdf['product'] == 6615) & (vdf[c].isin([2,4,6,8])))]
        
for c in columns:
    # print(c)
    temp = vdf.loc[(vdf['product'] == 15552) & (vdf[c].isin([5,7]))]
    rows += len(temp)
    if len(temp) > 0:
        vdf = vdf.loc[~((vdf['product'] == 15552) & (vdf[c].isin([5,7])))]

for c in columns:
    # print(c)
    temp = vdf.loc[(vdf['product'] == 420) & (vdf[c].isin([8,9]))]
    rows += len(temp)
    if len(temp) > 0:
        vdf = vdf.loc[~((vdf['product'] == 420) & (vdf[c].isin([8,9])))]

# %%
# Get each row from horizontal dataframe as tuple, add it to dictionary of lists of tuples

hdfdict = {}

for h in hdf.p.unique():
    temp = hdf.loc[(hdf['product'] == h)][['i','j','k']]
    temptuple = [tuple(r) for r in temp.to_numpy()]
    hdfdict[h] = temptuple
    
print(hdfdict)
# Out:
# {210: [(5, 6, 7), (5, 7, 6), (6, 5, 7), (6, 7, 5), (7, 5, 6), (7, 6, 5)], 144: [(2, 8, 9), (2, 9, 8), (3, 6, 8), (3, 8, 6), (4, 4, 9), (4, 6, 6), (4, 9, 4), (6, 3, 8), (6, 4, 6), (6, 6, 4), (6, 8, 3), (8, 2, 9), (8, 3, 6), (8, 6, 3), (8, 9, 2), (9, 2, 8), (9, 4, 4), (9, 8, 2)], 54: [(1, 6, 9), (1, 9, 6), (2, 3, 9), (2, 9, 3), (3, 2, 9), (3, 3, 6), (3, 6, 3), (3, 9, 2), (6, 1, 9), (6, 3, 3), (6, 9, 1), (9, 1, 6), (9, 2, 3), (9, 3, 2), (9, 6, 1)], 135: [(3, 5, 9), (3, 9, 5), (5, 3, 9), (5, 9, 3), (9, 3, 5), (9, 5, 3)], 4: [(1, 1, 4), (1, 2, 2), (1, 4, 1), (2, 1, 2), (2, 2, 1), (4, 1, 1)], 49: [(1, 7, 7), (7, 1, 7), (7, 7, 1)]}

# %%
# Rules
a = [2,4,6,8]
b = [5,7]
c = [8,9]

hdfdictres = {}

for k, v in hdfdict.items():
    tl = []
    for t in v:
        if t[0] not in a and t[1] not in b and t[2] not in c:
            tl.append(t)
            # print('Potential solution found.')
    hdfdictres[k] = tl

# %%
hdfdictres
# Out:
# {210: [(5, 6, 7), (7, 6, 5)],
#  144: [(3, 8, 6), (9, 4, 4), (9, 8, 2)],
#  54: [(1, 9, 6),
#   (3, 3, 6),
#   (3, 6, 3),
#   (3, 9, 2),
#   (9, 1, 6),
#   (9, 2, 3),
#   (9, 3, 2),
#   (9, 6, 1)],
#  135: [(3, 9, 5), (5, 9, 3), (9, 3, 5)],
#  4: [(1, 1, 4), (1, 2, 2), (1, 4, 1)],
#  49: [(7, 1, 7)]}
